# %%
import json
import pandas
import time
import os
import csv
from functools import reduce

# %%
inputDir = '..//scrapedData//'
outputDir = '..//summarizedData//'

## Load the id config
idConfig = json.loads(open('..//config//idConfig.json', "r").read())

## Load the source file dict
sourceFiles = json.loads(open('..//config//sourceFiles.json', "r").read())

# %%
## If there are multiple files for any given dataset, then this function will combine all of those
## records into a single dicti
def mergeSourceFiles (source, outputDir, sourceFiles):
    recordList = []
    for file in sourceFiles[source]:  
        file = json.loads(open(outputDir + file, "r", encoding="utf-8").read())
        for record in file:
            recordList.append(record)
    return recordList

# %%
allConfData = mergeSourceFiles('allConf', inputDir, sourceFiles)

# %%
## Clean up dirty names
def mungeID(playerString):
    return ''.join(e for e in playerString if e.isalnum()).lower().replace("jr.", "").replace("st.", "state")

# %%
def createNewID (fieldList, thisDict, fieldAgg):
    finalID= ''
    for i in thisDict:
        for idx, val in enumerate(fieldList):
            if (type(i[val]) is list):
                i[val]= mungeID(i[val][0])
                if (len(fieldList) -1 == idx):
                    finalID += str(i[val]).strip('[]').strip("''")
            elif (type(val) is not list):
                i[val] = mungeID(i[val])
                if (len(fieldList) - 1 == idx):
                    finalID += i[val]
                else:
                    finalID = i[val] + fieldAgg
        i['ID'] = finalID
        finalID=''

# %%
def search(name, team, dataList):
    return [element for element in dataList if (element['playerName'] == name and element['school'] == team)]

def searchID(identifier, dataList):
    return [element for element in dataList if (element['ID'] == identifier)]

# %%
createNewID(idConfig['allConf'], allConfData, '_')

# %%
finalOutput = []
for x in allConfData:
    if (len(searchID(x['ID'], finalOutput)) == 0):
        playerList = search(x['playerName'], x['school'], allConfData)
        finalPlayer = {}
        finalPlayer['ID'] = x['ID']
        finalPlayer['playerName'] = x['playerName']
        finalPlayer['school'] = x['school']
        year = 2021
        coaches = media = []
        for y in playerList:
            if ('Team' in y.keys()):
                if (y['Team'] == '1st'):
                    coaches.append('1')
                elif (y['Team'] == '2nd'):
                    coaches.append('2')
                else:
                    print (y)
            else:
                coaches.append(y['coaches'])
                media.append(y['media'])
        if (min(coaches) != '0'):
            finalPlayer['coaches'] = min(coaches)
        else:
            finalPlayer['coaches'] = 0
        if (min(media) != 0):
            finalPlayer['media'] = min(media)
        else:
            finalPlayer['media'] = 0
        finalOutput.append(finalPlayer)

# %%
print(finalOutput)
# Out:
# [{'ID': 'drewlock_missouri', 'playerName': 'drewlock', 'school': 'missouri', 'coaches': '1', 'media': '1'}, {'ID': 'jarrettstidham_auburn', 'playerName': 'jarrettstidham', 'school': 'auburn', 'coaches': '1', 'media': '1'}, {'ID': 'kerryonjohnson_auburn', 'playerName': 'kerryonjohnson', 'school': 'auburn', 'coaches': '1', 'media': '1'}, {'ID': 'bennysnelljr_kentucky', 'playerName': 'bennysnelljr', 'school': 'kentucky', 'coaches': '1', 'media': '1'}, {'ID': 'nickchubb_georgia', 'playerName': 'nickchubb', 'school': 'georgia', 'coaches': '1', 'media': '1'}, {'ID': 'derriusguice_lsu', 'playerName': 'derriusguice', 'school': 'lsu', 'coaches': '1', 'media': '1'}, {'ID': 'ajbrown_olemiss', 'playerName': 'ajbrown', 'school': 'olemiss', 'coaches': '1', 'media': '1'}, {'ID': 'calvinridley_alabama', 'playerName': 'calvinridley', 'school': 'alabama', 'coaches': '1', 'media': '1'}, {'ID': 'jmonmoore_missouri', 'playerName': 'jmonmoore', 'school': 'missouri', 'coaches': '1', 'media': '1'}, {'ID': 'christiankirk_texasam', 'playerName': 'christiankirk', 'school': 'texasam', 'coaches': '1', 'media': '1'}, {'ID': 'willclapp_lsu', 'playerName': 'willclapp', 'school': 'lsu', 'coaches': '1', 'media': '1'}, {'ID': 'bradleybozeman_alabama', 'playerName': 'bradleybozeman', 'school': 'alabama', 'coaches': '1', 'media': '1'}, {'ID': 'frankragnow_arkansas', 'playerName': 'frankragnow', 'school': 'arkansas', 'coaches': '1', 'media': '1'}, {'ID': 'bradensmith_auburn', 'playerName': 'bradensmith', 'school': 'auburn', 'coaches': '1', 'media': '1'}, {'ID': 'rosspierschbacher_alabama', 'playerName': 'rosspierschbacher', 'school': 'alabama', 'coaches': '1', 'media': '1'}, {'ID': 'greglittle_olemiss', 'playerName': 'greglittle', 'school': 'olemiss', 'coaches': '1', 'media': '1'}, {'ID': 'treysmith_tennessee', 'playerName': 'treysmith', 'school': 'tennessee', 'coaches': '1', 'media': '1'}, {'ID': 'garrettbrumfield_lsu', 'playerName': 'garrettbrumfield', 'school': 'lsu', 'coaches': '2', 'media': '2'}, {'ID': 'jonahwilliams_alabama', 'playerName': 'jonahwilliams', 'school': 'alabama', 'coaches': '1', 'media': '1'}, {'ID': 'isaiahwynn_georgia', 'playerName': 'isaiahwynn', 'school': 'georgia', 'coaches': '1', 'media': '1'}, {'ID': 'martinasrankin_missst', 'playerName': 'martinasrankin', 'school': 'missst', 'coaches': '1', 'media': '1'}, {'ID': 'martezivey_florida', 'playerName': 'martezivey', 'school': 'florida', 'coaches': '2', 'media': '2'}, {'ID': 'haydenhurst_southcarolina', 'playerName': 'haydenhurst', 'school': 'southcarolina', 'coaches': '1', 'media': '1'}, {'ID': 'albertokwuegbunam_missouri', 'playerName': 'albertokwuegbunam', 'school': 'missouri', 'coaches': '1', 'media': '1'}, {'ID': 'jeffholland_auburn', 'playerName': 'jeffholland', 'school': 'auburn', 'coaches': '1', 'media': '1'}, {'ID': 'montezsweat_missst', 'playerName': 'montezsweat', 'school': 'missst', 'coaches': '1', 'media': '1'}, {'ID': 'marcellfrazier_missouri', 'playerName': 'marcellfrazier', 'school': 'missouri', 'coaches': '2', 'media': '2'}, {'ID': 'marquishaynes_olemiss', 'playerName': 'marquishaynes', 'school': 'olemiss', 'coaches': '2', 'media': '2'}, {'ID': 'dantesawyer_southcarolina', 'playerName': 'dantesawyer', 'school': 'southcarolina', 'coaches': '2', 'media': '2'}, {'ID': 'dashawnhand_alabama', 'playerName': 'dashawnhand', 'school': 'alabama', 'coaches': '2', 'media': '2'}, {'ID': 'jefferysimmons_missst', 'playerName': 'jefferysimmons', 'school': 'missst', 'coaches': '1', 'media': '1'}, {'ID': 'daronpayne_alabama', 'playerName': 'daronpayne', 'school': 'alabama', 'coaches': '1', 'media': '1'}, {'ID': 'raekwondavis_alabama', 'playerName': 'raekwondavis', 'school': 'alabama', 'coaches': '1', 'media': '1'}, {'ID': 'tavenbryan_florida', 'playerName': 'tavenbryan', 'school': 'florida', 'coaches': '1', 'media': '1'}, {'ID': 'breelandspeaks_olemiss', 'playerName': 'breelandspeaks', 'school': 'olemiss', 'coaches': '1', 'media': '1'}, {'ID': 'roquansmith_georgia', 'playerName': 'roquansmith ...

# %%
##Delete the columns I no longer care about after creating the ID
##This list will need to expand after setting up blockers and truly linking
for record in finalOutput:
    del record['playerName']
    del record['school']

# %%
with open(outputDir + "allConf.json", "w", encoding="utf-8") as write_file:
                write_file.write(json.dumps(finalOutput))
