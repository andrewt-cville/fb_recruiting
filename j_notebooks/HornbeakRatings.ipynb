# %%
import queries
import csv
import functions as fx
import pandas as pd

# %%
rankings = [5,4,3,2,1]
for ranking in rankings:
    query = queries.get_query_KevinRating(ranking)
    temp = (fx.connDBAndReturnDF(query))
    if (ranking == 5):
        fivestars = temp
        print(fivestars.shape[0])
    elif (ranking == 4):
        fourstars = temp.query("ID not in @fivestars.ID")
        print(fourstars.shape[0])
    elif (ranking == 3):
        threestars = temp.query("ID not in @fourstars.ID")
        print(threestars.shape[0])
    elif (ranking == 2):
        twostars = temp.query("ID not in @threestars.ID")
        print(twostars.shape[0])
    elif (ranking == 1):
        onestar = temp.query("ID not in @twostars.ID")
        print(onestar.shape[0])
    del temp
# Out:
# 876
# 3070
# 9303
# 11312
# 46898

# %%
frames = [fivestars, fourstars, threestars, twostars, onestar]
allplayers = pd.concat(frames)
print(allplayers.shape[0])
# Out:
# 71459

# %%
allplayers.to_csv(path_or_buf = 'allplayers.csv', sep = ',')

# %%
pd.set_option('display.max_columns', None)
allplayers
# Out:
#                                   ID                         IDYR  \
# 0                    aaronross_texas         aaronross_texas_2002
# 1              adamcarriker_nebraska   adamcarriker_nebraska_2002
# 2             adamjones_westvirginia  adamjones_westvirginia_2002
# 3                   ajhawk_ohiostate        ajhawk_ohiostate_2002
# 4                     alexsmith_utah          alexsmith_utah_2002
# ...                              ...                          ...
# 46941          zykeiusstrong_houston                         None
# 46942           zylanperry_louisiana                         None
# 46943           zymcdonald_louisiana                         None
# 46944              zymircobbs_temple                         None
# 46945  zyunreeves_northcarolinastate                         None
#
#                   College conference  Year     PlayerName   HighSchool  \
# 0                   texas  bigtwelve  2002      aaronross   John Tyler
# 1                nebraska     bigten  2002   adamcarriker    Kennewick
# 2            westvirginia  bigtwelve  2002      adamjones     Westlake
# 3               ohiostate     bigten  2002         ajhawk  Centerville
# 4                    utah  pactwelve  2002      alexsmith        Helix
# ...                   ...        ...   ...            ...          ...
# 46941             houston       None  2021  zykeiusstrong         None
# 46942           louisiana       None  2021     zylanperry         None
# 46943           louisiana       None  2021     zymcdonald         None
# 46944              temple       None  2021     zymircobbs         None
# 46945  northcarolinastate       None  2021     zyunreeves         None
#
#             City State Position  Height  Weight CompositeRating  \
# 0          Tyler    TX       DB    73.0   180.0             0.9
# 1      Kennewick    WA       DE    78.0   235.0             0.8
# 2        Atlanta    GA       DB    72.0   185.0          0.7667
# 3         Dayton    OH       LB    74.0   230.0          0.8333
# 4        La Mesa    CA       QB    75.0   190.0          0.7667
# ...          ...   ...      ...     ...     ...             ...
# 46941       None  None       DL     NaN     NaN            None
# 46942       None  None       RB     NaN     NaN            None
# 46943       None  None       QB     NaN     NaN            None
# 46944       None  None       DL     NaN     NaN            None
# 46945       None  None       DL     NaN     NaN            None
#
#        CompositeStars  CompositeNationalRank  CompositePositionRank  \
# 0                   4                  158.0                    9.0
# 1                   3                  694.0                   41.0
# 2                   2                    NaN                  142.0
# 3                   3                  543.0                   28.0
# 4                   2                    NaN                   39.0
# ...               ...                    ...                    ...
# 46941               1                    NaN                    NaN
# 46942               1                    NaN                    NaN
# 46943               1                    NaN                    NaN
# 46944               1                    NaN                    NaN
# 46945               1                    NaN                    NaN
#
#        CompositeStateRank  Rating247  Stars247  NationalRank247  \
# 0                    25.0        NaN         1              NaN
# 1                    10.0        NaN         1              NaN
# 2                    89.0        NaN         1              NaN
# 3                    24.0        NaN         1              NaN
# 4                   137.0        NaN         1              NaN
# ...                   ...        ...       ...              ...
# 46941                 NaN        NaN         1              NaN
# 46942                 NaN        NaN         1              NaN
# 46943                 NaN        NaN         1              NaN
# 46944                 NaN        NaN         1              NaN
# 46945                 NaN        NaN         1              NaN
#
#        PositionRank247  StateRank247  StarsRivals  NationalRankRivals  \
# 0                  NaN           NaN            4                 NaN
# 1                  NaN           NaN            3                 NaN
# 2                  NaN           NaN            2                 NaN
# 3                  NaN           NaN            3                 NaN
# 4                  NaN           NaN            2                 NaN
# ...                ...           ...          ...                 ...
# 46941              NaN           NaN            1                 NaN
# 46942              NaN           NaN            1                 NaN
# 46943              NaN           NaN            1                 NaN
# 46944              NaN           NaN            1                 NaN
# 46945              NaN           NaN            1                 NaN
#
#        PositionRankRivals  StateRankRivals  NFLDraftRound  NFLDraftPick  \
# 0                     NaN              NaN            1.0          20.0
# 1                    46.0              NaN            1.0          13.0
# 2                    71.0              NaN            1.0           6.0
# 3                    30.0              NaN            1.0           5.0
# 4                     NaN              NaN            1.0           1.0
# ...                   ...              ...            ...           ...
# 46941                 NaN              NaN            NaN           NaN
# 46942                 NaN              NaN            NaN           NaN
# 46943                 NaN              NaN            NaN           NaN
# 46944                 NaN              NaN            NaN           NaN
# 46945                 NaN              NaN            NaN           NaN
#
#        NFLAllProFirstTeam  NFLProBowl  NFLYearsAsStarter NFLGamesPlayed  \
# 0                     0.0         0.0                4.0             83
# 1                     0.0         0.0                3.0             65
# 2                     1.0         1.0                6.0            146
# 3                     0.0         0.0               10.0            159
# 4                     0.0         3.0               14.0            174
# ...                   ...         ...                ...            ...
# 46941                 NaN         NaN                NaN           None
# 46942                 NaN         NaN                NaN           None
# 46943                 NaN         NaN                NaN           None
# 46944                 NaN         NaN                NaN           None
# 46945                 NaN         NaN                NaN           None
#
#        AllConferenceTeam_Best  NCAAGamesPlayed  NCAAGamesStarted  \
# 0                         1.0              NaN               NaN
# 1                         1.0              NaN               NaN
# 2                         1.0              NaN               NaN
# 3                         1.0              NaN               NaN
# 4                         1.0              NaN               NaN
# ...                       ...              ...               ...
# 46941                     NaN              0.0               0.0
# 46942                     NaN              1.0               0.0
# 46943                     NaN              1.0               0.0
# 46944                     NaN              1.0               0.0
# 46945                     NaN              2.0               0.0
#
#        AllAmericanBest  HornbeakRating
# 0                  NaN               5
# 1                  NaN               5
# 2                  1.0               5
# 3                  1.0               5
# 4                  1.0               5
# ...                ...             ...
# 46941              NaN               1
# 46942              NaN               1
# 46943              NaN               1
# 46944              NaN               1
# 46945              NaN               1
#
# [71459 rows x 37 columns]

# %%
fivestars
# Out:
#                               ID                         IDYR        College  \
# 0                aaronross_texas         aaronross_texas_2002          texas
# 1          adamcarriker_nebraska   adamcarriker_nebraska_2002       nebraska
# 2         adamjones_westvirginia  adamjones_westvirginia_2002   westvirginia
# 3               ajhawk_ohiostate        ajhawk_ohiostate_2002      ohiostate
# 4                 alexsmith_utah          alexsmith_utah_2002           utah
# ..                           ...                          ...            ...
# 871  joetryonshoyinka_washington                         None     washington
# 872       justinfields_ohiostate                         None      ohiostate
# 873           mikerose_iowastate                         None      iowastate
# 874          odafeoweh_pennstate                         None      pennstate
# 875      treylance_northdakotast                         None  northdakotast
#
#     conference  Year        PlayerName   HighSchool       City State Position  \
# 0    bigtwelve  2002         aaronross   John Tyler      Tyler    TX       DB
# 1       bigten  2002      adamcarriker    Kennewick  Kennewick    WA       DE
# 2    bigtwelve  2002         adamjones     Westlake    Atlanta    GA       DB
# 3       bigten  2002            ajhawk  Centerville     Dayton    OH       LB
# 4    pactwelve  2002         alexsmith        Helix    La Mesa    CA       QB
# ..         ...   ...               ...          ...        ...   ...      ...
# 871  pactwelve  2021  joetryonshoyinka         None       None  None       LB
# 872       None  2021      justinfields         None       None  None       QB
# 873       None  2021          mikerose         None       None  None       LB
# 874       None  2021         odafeoweh         None       None  None       DE
# 875       None  2021         treylance         None       None  None       QB
#
#      Height  Weight CompositeRating  CompositeStars  CompositeNationalRank  \
# 0      73.0   180.0             0.9               4                  158.0
# 1      78.0   235.0             0.8               3                  694.0
# 2      72.0   185.0          0.7667               2                    NaN
# 3      74.0   230.0          0.8333               3                  543.0
# 4      75.0   190.0          0.7667               2                    NaN
# ..      ...     ...             ...             ...                    ...
# 871     NaN     NaN            None               1                    NaN
# 872     NaN     NaN            None               1                    NaN
# 873     NaN     NaN            None               1                    NaN
# 874     NaN     NaN            None               1                    NaN
# 875     NaN     NaN            None               1                    NaN
#
#      CompositePositionRank  CompositeStateRank  Rating247  Stars247  \
# 0                      9.0                25.0        NaN         1
# 1                     41.0                10.0        NaN         1
# 2                    142.0                89.0        NaN         1
# 3                     28.0                24.0        NaN         1
# 4                     39.0               137.0        NaN         1
# ..                     ...                 ...        ...       ...
# 871                    NaN                 NaN        NaN         1
# 872                    NaN                 NaN        NaN         1
# 873                    NaN                 NaN        NaN         1
# 874                    NaN                 NaN        NaN         1
# 875                    NaN                 NaN        NaN         1
#
#      NationalRank247  PositionRank247  StateRank247  StarsRivals  \
# 0                NaN              NaN           NaN            4
# 1                NaN              NaN           NaN            3
# 2                NaN              NaN           NaN            2
# 3                NaN              NaN           NaN            3
# 4                NaN              NaN           NaN            2
# ..               ...              ...           ...          ...
# 871              NaN              NaN           NaN            1
# 872              NaN              NaN           NaN            1
# 873              NaN              NaN           NaN            1
# 874              NaN              NaN           NaN            1
# 875              NaN              NaN           NaN            1
#
#      NationalRankRivals  PositionRankRivals  StateRankRivals  NFLDraftRound  \
# 0                   NaN                 NaN              NaN            1.0
# 1                   NaN                46.0              NaN            1.0
# 2                   NaN                71.0              NaN            1.0
# 3                   NaN                30.0              NaN            1.0
# 4                   NaN                 NaN              NaN            1.0
# ..                  ...                 ...              ...            ...
# 871                 NaN                 NaN              NaN            1.0
# 872                 NaN                 NaN              NaN            1.0
# 873                 NaN                 NaN              NaN            NaN
# 874                 NaN                 NaN              NaN            1.0
# 875                 NaN                 NaN              NaN            1.0
#
#      NFLDraftPick  NFLAllProFirstTeam  NFLProBowl  NFLYearsAsStarter  \
# 0            20.0                 0.0         0.0                4.0
# 1            13.0                 0.0         0.0                3.0
# 2             6.0                 1.0         1.0                6.0
# 3             5.0                 0.0         0.0               10.0
# 4             1.0                 0.0         3.0               14.0
# ..            ...                 ...         ...                ...
# 871          32.0                 0.0         0.0                0.0
# 872          11.0                 0.0         0.0                0.0
# 873           NaN                 NaN         NaN                NaN
# 874          31.0                 0.0         0.0                0.0
# 875           3.0                 0.0         0.0                0.0
#
#     NFLGamesPlayed  AllConferenceTeam_Best  NCAAGamesPlayed  NCAAGamesStarted  \
# 0               83                     1.0              NaN               NaN
# 1               65                     1.0              NaN               NaN
# 2              146                     1.0              NaN               NaN
# 3              159                     1.0              NaN               NaN
# 4              174                     1.0              NaN               NaN
# ..             ...                     ...              ...               ...
# 871             23                     NaN              NaN               NaN
# 872             18                     NaN              NaN               NaN
# 873           None                     1.0              NaN               NaN
# 874             21                     NaN              NaN               NaN
# 875              8                     NaN              NaN               NaN
#
#      AllAmericanBest  HornbeakRating
# 0                NaN               5
# 1                NaN               5
# 2                1.0               5
# 3                1.0               5
# 4                1.0               5
# ..               ...             ...
# 871              NaN               5
# 872              NaN               5
# 873              1.0               5
# 874              NaN               5
# 875              NaN               5
#
# [876 rows x 37 columns]

# %%
fx.connAndWriteDB(allplayers, 'HornbeakRatings')
